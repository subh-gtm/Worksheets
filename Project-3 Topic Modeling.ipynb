# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
data = pd.read_csv('news.csv', error_bad_lines=False);
data_text = data[['content']]
data_text['index'] = data_text.index
documents = data_text

# %%
print(len(documents))
print(documents[:9])
# Out:
# 50000
#                                              content  index
# 0  WASHINGTON  —   Congressional Republicans have...      0
# 1  After the bullet shells get counted, the blood...      1
# 2  When Walt Disney’s “Bambi” opened in 1942, cri...      2
# 3  Death may be the great equalizer, but it isn’t...      3
# 4  SEOUL, South Korea  —   North Korea’s leader, ...      4
# 5  LONDON  —   Queen Elizabeth II, who has been b...      5
# 6  BEIJING  —   President Tsai   of Taiwan sharpl...      6
# 7  Danny Cahill stood, slightly dazed, in a blizz...      7
# 8  Just how   is Hillary Kerr, the    founder of ...      8

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import PorterStemmer
from nltk import PorterStemmer
PorterStemmer().stem('complications')
import numpy as np
np.random.seed(2018)
import pandas as pd
stemmer = SnowballStemmer("english")
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\subhg\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))
def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
doc_sample = documents[documents['index'] == 4310].values[0][0]
print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample))
# Out:
# original document:
# ['July', '1939.', 'The', 'world', 'teetered', 'on', 'the', 'brink', 'of', 'war', 'as', 'Hitler', 'menaced', 'Poland.', 'The', '11', 'millionth', 'visitor', 'passed', 'through', 'the', 'turnstiles', 'of', 'the', 'New', 'York', 'World’s', 'Fair.', 'Baseball', 'fans', 'still', 'reeled', 'after', 'Lou', 'Gehrig’s', '“luckiest', 'man”', 'speech', 'at', 'Yankee', 'Stadium.', 'But', 'many', 'Americans', 'could', 'think', 'only', 'of', 'Donn', 'Fendler,', 'a', '', '', '', 'boy', 'lost', 'on', 'Mount', 'Katahdin', 'in', 'Maine,', 'the', 'object', 'of', 'a', 'frantic', 'search', 'and', 'rescue', 'operation', 'that', 'dragged', 'on', 'for', 'nine', 'days,', 'monopolizing', 'the', 'radio', 'airwaves', 'and', 'newspaper', 'headlines.', 'Thousands', 'of', 'mothers', 'sent', 'prayers', 'by', 'Western', 'Union', 'to', 'the', 'boy’s', 'mother.', 'Boy', 'Scouts', 'joined', 'the', 'search,', 'along', 'with', 'workers', 'from', 'the', 'Millinocket', 'paper', 'mill.', 'The', 'New', 'York', 'State', 'Police', 'dispatched', 'two', 'of', 'their', 'best', 'bloodhounds', 'by', 'air.', 'Hearts', 'sank', 'when', 'Donn’s', 'footprints', 'disappeared', 'at', 'the', 'edge', 'of', 'a', 'sheer', '', '', 'precipice', 'called', 'Saddle', 'Slip.', '“I’m', 'still', 'trying', 'to', 'make', 'myself', 'believe', 'there’s', 'a', 'faint', 'thread', 'of', 'hope,”', 'his', 'despondent', 'father,', 'Donald,', 'told', 'The', 'Boston', 'Globe.', 'Spirits', 'lifted', 'when', 'new', 'footprints', 'appeared', 'near', 'the', 'mountain’s', 'base', 'two', 'days', 'later.', 'Finally,', 'on', 'the', 'ninth', 'day,', 'a', 'miracle.', '“Stripped', 'naked', 'by', 'eight', 'days', 'of', 'fearful', 'battling', 'with', 'the', 'Maine', 'wilderness', 'on', 'the', 'slopes', 'of', '', '', 'Mount', 'Katahdin,', 'Donn', 'Fendler', 'came', 'back', 'to', 'civilization', 'this', 'afternoon', '', '—', '', '', 'wan,', 'cruelly', 'bitten', 'and', 'scratched,', 'delirious', 'with', 'joy', 'at', 'hearing', 'a', 'human', 'voice', 'again,”', 'The', 'Globe', 'reported', 'on', 'July', '26,', 'under', 'the', 'headline', '“Boy', 'Found', 'in', 'Maine', 'Wilds.', '”', 'The', 'national', 'ordeal', 'was', 'over.', 'Donn', 'Fendler', 'died', 'on', 'Sunday', 'in', 'Bangor,', 'Me.', 'his', 'son,', 'Dennis,', 'said.', 'Mr.', 'Fendler', 'was', '90.', 'The', 'Fendlers,', 'from', 'Rye,', 'N.', 'Y.', 'had', 'spent', 'the', 'previous', 'four', 'summers', 'vacationing', 'on', 'Sebasticook', 'Lake', 'in', 'Newport,', 'in', 'the', 'center', 'of', 'Maine.', 'On', 'July', '17,', 'Donald', 'Fendler', 'and', 'his', 'sons,', 'Ryan,', 'Donn', 'and', 'Tommy,', 'Donn’s', 'twin,', 'headed', 'out', 'after', 'lunch', 'to', 'ascend', 'Mount', 'Katahdin,', 'at', '5,', '267', 'feet', 'the', 'state’s', 'highest', 'peak.', 'They', 'were', 'accompanied', 'by', 'Henry', 'Condon,', 'the', '', '', '', 'son', 'of', 'a', 'local', 'guide,', 'and', 'Fred', 'Eaton,', 'a', 'young', 'family', 'friend.', 'Eager', 'to', 'climb,', 'Donn', 'left', 'his', 'father', 'and', 'brothers', 'behind,', 'pushing', 'on', 'with', 'Henry', 'and', 'Fred,', 'when', 'bad', 'weather', 'set', 'in.', '“Just', 'as', 'we', 'reached', 'the', 'summit,', 'the', 'mist', 'closed', 'in', 'around', 'us', 'and', 'shut', 'off', 'our', 'view', 'of', 'the', 'mountain', 'below,”', 'he', 'said', 'in', '“Lost', 'on', 'a', 'Mountain', 'in', 'Maine”', '(1939)', 'an', '', '', '', 'account', 'of', 'his', 'adventure', 'written', 'with', 'Joseph', 'B.', 'Egan.', 'Ignoring', 'the', 'advice', 'of', 'his', 'climbing', 'mates,', 'Donn', 'headed', 'back', 'to', 'rejoin', 'his', 'family.', 'Lashed', 'by', 'rain', 'and', 'disoriented', 'by', 'the', 'enveloping', 'mist,', 'he', 'quickly', 'became', 'lost.', 'And', 'thus', 'began', 'his', 'weeklong', 'odyssey.', 'Recalling', 'his', 'Boy', 'Scout', 'training,', 'he', 'decided', 'to', 'follow', 'a', 'small', 'stream', 'toward', 'what', 'he', 'hoped', 'would', 'be', 'a', 'camp', 'or', 'town.', 'At', 'night,', 'he', 'curled', 'up', 'between', 'tree', 'ro ...
#
#
#  tokenized and lemmatized document:
# ['juli', 'world', 'teeter', 'brink', 'hitler', 'menac', 'poland', 'millionth', 'visitor', 'pass', 'turnstil', 'york', 'world', 'fair', 'basebal', 'fan', 'reel', 'gehrig', 'luckiest', 'speech', 'yanke', 'stadium', 'american', 'think', 'donn', 'fendler', 'lose', 'mount', 'katahdin', 'main', 'object', 'frantic', 'search', 'rescu', 'oper', 'drag', 'day', 'monopol', 'radio', 'airwav', 'newspap', 'headlin', 'thousand', 'mother', 'send', 'prayer', 'western', 'union
'yell', 'fendler', 'say', 'book', 'guess', 'yell', 'pretti', 'funni', 'mcmoarn', 'tell', 'later', 'sound', 'like', 'screech', 'carri', 'lena', 'mcmoarn', 'nelson', 'wife', 'reviv', 'coffe', 'soup', 'donn', 'hand', 'telephon', 'receiv', 'mother', 'line', 'mama', 'right', 'tell', 'scratch', 'swell', 'eat', 'aliv', 'insect', 'pound', 'lighter', 'wander', 'mile', 'start', 'point', 'aliv', 'news', 'page', 'york', 'time', 'fold', 'life', 'magazin', 'publish', 'photo', 'spread', 'littl', 'year', 'later', 'donn', 'white', 'hous', 'presid', 'franklin', 'roosevelt', 'award', 'armi', 'navi', 'legion', 'valor', 'medal', 'recogn', 'outstand', 'youth', 'hero', 'donn', 'conner', 'fendler', 'bear', 'father', 'help', 'famili', 'busi', 'almi', 'cleric', 'vestment', 'church', 'good', 'mother', 'ruth', 'ryan', 'homemak', 'transport', 'cano', ' ...

# %%
processed_docs = documents['content'].map(preprocess)
processed_docs[:10]
# Out:
# 0    [washington, congression, republican, fear, co...
# 1    [bullet, shell, count, blood, dri, votiv, cand...
# 2    [walt, disney, bambi, open, critic, prais, spa...
# 3    [death, great, equal, necessarili, evenhand, f...
# 4    [seoul, south, korea, north, korea, leader, sa...
# 5    [london, queen, elizabeth, battl, cold, week, ...
# 6    [beij, presid, tsai, taiwan, sharpli, critic, ...
# 7    [danni, cahil, stand, slight, daze, blizzard, ...
# 8    [hillari, kerr, founder, digit, media, compani...
# 9    [angel, muñiz, famili, apart, bronx, paint, an...
# Name: content, dtype: object

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 10:
        break
# Out:
# 0 access
# 1 acknowledg
# 2 administr
# 3 advoc
# 4 afford
# 5 alli
# 6 american
# 7 anger
# 8 annual
# 9 anticip
# 10 appeal

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
bow_corpus[4310]
# Out:
# [(6, 1),
#  (22, 1),
#  (36, 2),
#  (51, 1),
#  (74, 2),
#  (77, 1),
#  (89, 1),
#  (101, 1),
#  (106, 1),
#  (108, 1),
#  (127, 4),
#  (132, 1),
#  (138, 7),
#  (145, 4),
#  (146, 1),
#  (154, 1),
#  (184, 2),
#  (187, 1),
#  (193, 1),
#  (196, 1),
#  (201, 2),
#  (209, 3),
#  (213, 3),
#  (226, 6),
#  (237, 1),
#  (243, 1),
#  (248, 1),
#  (253, 1),
#  (269, 1),
#  (272, 3),
#  (275, 1),
#  (288, 1),
#  (295, 2),
#  (300, 2),
#  (316, 1),
#  (325, 1),
#  (331, 1),
#  (338, 3),
#  (356, 1),
#  (359, 2),
#  (362, 1),
#  (370, 1),
#  (391, 2),
#  (400, 1),
#  (415, 1),
#  (416, 4),
#  (420, 1),
#  (458, 1),
#  (459, 1),
#  (462, 1),
#  (464, 1),
#  (479, 1),
#  (480, 1),
#  (481, 3),
#  (500, 1),
#  (507, 1),
#  (514, 3),
#  (541, 2),
#  (544, 3),
#  (549, 1),
#  (553, 1),
#  (564, 1),
#  (565, 1),
#  (570, 1),
#  (597, 1),
#  (598, 1),
#  (607, 1),
#  (616, 2),
#  (621, 1),
#  (625, 1),
#  (630, 1),
):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_4310[i][0], 
                                               dictionary[bow_doc_4310[i][0]], 
bow_doc_4310[i][1]))
# Out:
# Word 6 ("american") appears 1 time.
# Word 22 ("branch") appears 1 time.
# Word 36 ("come") appears 2 time.
# Word 51 ("continu") appears 1 time.
# Word 74 ("donald") appears 2 time.
# Word 77 ("eager") appears 1 time.
# Word 89 ("fear") appears 1 time.
# Word 101 ("hand") appears 1 time.
# Word 106 ("hous") appears 1 time.
# Word 108 ("illustr") appears 1 time.
# Word 127 ("later") appears 4 time.
# Word 132 ("leav") appears 1 time.
# Word 138 ("lose") appears 7 time.
# Word 145 ("mount") appears 4 time.
# Word 146 ("nation") appears 1 time.
# Word 154 ("pass") appears 1 time.
# Word 184 ("quick") appears 2 time.
# Word 187 ("receiv") appears 1 time.
# Word 193 ("report") appears 1 time.
# Word 196 ("requir") appears 1 time.
# Word 201 ("right") appears 2 time.
# Word 209 ("spend") appears 3 time.
# Word 213 ("state") appears 3 time.
# Word 226 ("tell") appears 6 time.
# Word 237 ("view") appears 1 time.
# Word 243 ("white") appears 1 time.
# Word 248 ("account") appears 1 time.
# Word 253 ("addit") appears 1 time.
# Word 269 ("appear") appears 1 time.
# Word 272 ("armi") appears 3 time.
# Word 275 ("ash") appears 1 time.
# Word 288 ("away") appears 1 time.
# Word 295 ("believ") appears 2 time.
# Word 300 ("black") appears 2 time.
# Word 316 ("briefli") appears 1 time.
# Word 325 ("busi") appears 1 time.
# Word 331 ("call") appears 1 time.
# Word 338 ("carri") appears 3 time.
# Word 356 ("civil") appears 1 time.
# Word 359 ("clear") appears 2 time.
# Word 362 ("close") appears 1 time.
# Word 370 ("command") appears 1 time.
# Word 391 ("corner") appears 2 time.
# Word 400 ("cover") appears 1 time.
# Word 415 ("daughter") appears 1 time.
# Word 416 ("day") appears 4 time.
# Word 420 ("decid") appears 1 time.
# Word 458 ("east") appears 1 time.
# Word 459 ("edg") appears 1 time.
# Word 462 ("emerg") appears 1 time.
# Word 464 ("encount") appears 1 time.
# Word 479 ("faith") appears 1 time.
# Word 480 ("fall") appears 1 time.
# Word 481 ("famili") appears 3 time.
# Word 500 ("fold") appears 1 time.
# Word 507 ("friend") appears 1 time.
# Word 514 ("go") appears 3 time.
# Word 541 ("head") appears 2 time.
# Word 544 ("hear") appears 3 time.
# Word 549 ("help") appears 1 time.
# Word 553 ("highest") appears 1 time.
# Word 564 ("hop") appears 1 time.
# Word 565 ("hospit") appears 1 time.
# Word 570 ("ignor") appears 1 time.
# Word 597 ("join") appears 1 time.
# Word 598 ("joseph") appears 1 time.
# Word 607 ("know") appears 1 time.
# Word 616 ("life") appears 2 time.
# Word 621 ("littl") appears 1 time.
# Word 625 ("local") appears 1 time.
# Word 630 ("long") appears 1 time.
# Word 637 ("make") appears 1 time.
# Word 648 ("menac") appears 1 time.
# Word 653 ("mile") appears 1 time.
# Word 662 ("mother") appears 4 time.
# Word 664 ("move") appears 1 time.
# Word 670 ("near") appears 1 time.
# Word 679 ("newspap") appears 1 time.
# Word 691 ("oper") appears 1 time.
# Word 702 ("paper") appears 1 time.
# Word 708 ("park") appears 1 time.
# Word 725 ("polic") appears 1 time.
# Word 729 ("post") appears 1 time.
# Word 730 ("pound") appears 1 time.
# Word 736 ("presid") appears 1 time.
# Word 754 ("push") appears 1 time.
# Word 795 ("resum") appears 1 time.
# Word 797 ("retir") appears 1 time.
# Word 806 ("river") appears 1 time.
# Word 815 ("routin") appears 1 time.
# Word 820 ("saddl") appears 1 time.
# Word 829 ("school") appears 2 time.
# Word 830 ("second") appears 1 time.
# Word 834 ("send") appears 1 time.
# Word 858 ("slip") appears 1 time.
# Word 859 ("small") appears 3 time.
# Word 865 ("son") appears 1 time.
# Word 881 ("start") appears 1 time.
# Word 892 ("stori") appears 2 time.
# Word 899 ("strip") appears 1 time.
# Word 908 ("summer") appears 2 time.
# Word 920 ("tale") appears 1 time.
# Word 921 ("talk") appears 1 time.
# Word 930 ("terribl") appears 1 time.
# Word 934 ("think") appears 1 time.
# Word 940 ("tie") appears 1 time.
# Word 944 ("trail") appears 1 time.
# Word 945 ("tri") appears 2 time.
# Word 949 ("twice") appears 1 time.
# Word 958 ("union") appears 1 time.
# Word 973 ("visit") appears 1 time.
# Word 976 ("walk") appears 1 time.
# Word 977 ("wander") appears 1 time.
# Word 981 ("watch") appears 1 time.
# Word 982 ("wave") appears 1 time.
# Word 989 ("wife") appears 1 time.
# Word 992 ("wire") appears 1 time.
# Word 998 ("worker") appears 1 time.
# Word 1003 ("write") appears 1 time.
# Word 1005 ("york") appears 3 time.
# Word 1006 ("young") appears 1 time.
# Word 1029 ("assum") appears 1 time.
# Word 1032 ("attend") appears 1 time.
# Word 1039 ("bear") appears 2 time.
# Word 1040 ("begin") appears 3 time.
# Word 1047 ("book") appears 3 time.
# Word 1050 ("brother") appears 3 time.
# Word 1060 ("camp") appears 3 time.
# Word 1063 ("career") appears 1 time.
# Word 1066 ("center") appears 1 time.
# Word 1105 ("die") appears 1 time.
# Word 1145 ("father") appears 3 time.
# Word 1148 ("feet") appears 2 time.
# Word 1160 ("follow") appears 1 time.
# Word 1169 ("fred") appears 2 time.
# Word 1175 ("good") appears 1 time.
# Word 1176 ("graduat") appears 1 time.
# Word 1177 ("grandchildren") appears 1 time.
# Word 1190 ("hope") appears 3 time.
# Word 1213 ("juli") appears 4 time.
# Word 1217 ("lake") appears 2 time.
# Word 1228 ("line") appears 1 time.
# Word 1253 ("mountain") appears 4 time.
# Word 1261 ("night") appears 2 time.
# Word 1264 ("novel") appears 1 time.
# Word 1274 ("outstand") appears 1 time.
# Word 1293 ("previous") appears 1 time.
# Word 1303 ("rank") appears 1 time.
# Word 1304 ("reach") appears 1 time.
# Word 1306 ("recal") appears 2 time.
# Word 1320 ("ruth") appears 1 time.
# Word 1335 ("sight") appears 1 time.
# Word 1358 ("studi") appears 1 time.
# Word 1361 ("suggest") appears 1 time.
# Word 1368 ("thousand") appears 1 time.
# Word 1371 ("train") appears 2 time.
# Word 1373 ("tree") appears 1 time.
# Word 1378 ("univers") appears 2 time.
# Word 1390 ("water") appears 1 time.
# Word 1392 ("weather") appears 1 time.
# Word 1394 ("west") appears 1 time.
# Word 1396 ("wild") appears 2 time.
# Word 1398 ("wood") appears 1 time.
# Word 1399 ("world") appears 3 time.
# Word 1408 ("adventur") appears 1 time.
# Word 1412 ("aliv") appears 2 time.
# Word 1434 ("basebal") appears 1 time.
# Word 1436 ("battl") appears 1 time.
# Word 1525 ("eye") appears 1 time.
# Word 1527 ("fan") appears 1 time.
# Word 1539 ("final") appears 1 time.
# Word 1579 ("guess") appears 1 time.
# Word 1585 ("hair") appears 1 time.
# Word 1599 ("henri") appears 2 time.
# Word 1690 ("nelson") appears 2 time.
# Word 1693 ("news") appears 3 time.
# Word 1727 ("poland") appears 1 time.
# Word 1762 ("rock") appears 1 time.
# Word 1766 ("root") appears 1 time.
# Word 1780 ("search") appears 2 time.
# Word 1790 ("serv") appears 2 time.
# Word 1800 ("shoulder") appears 1 time.
# Word 1811 ("sound") appears 1 time.
# Word 1814 ("spirit") appears 1 time.
# Word 1817 ("spread") appears 1 time.
# Word 1844 ("throw") appears 1 time.
# Word 1851 ("trip") appears 1 time.
# Word 1861 ("vietnam") appears 1 time.
# Word 1865 ("voic") appears 1 time.
# Word 1870 ("wilder") appears 1 time.
# Word 1886 ("base") appears 2 time.
# Word 1913 ("pacif") appears 1 time.
# Word 1931 ("speech") appears 1 time.
# Word 1934 ("sunday") appears 1 time.
# Word 1942 ("ascend") appears 1 time.
# Word 1946 ("church") appears 1 time.
# Word 1951 ("king") appears 1 time.
# Word 1989 ("dispatch") appears 1 time.
# Word 2003 ("messag") appears 2 time.
# Word 2033 ("strength") appears 1 time.
# Word 2062 ("best") appears 1 time.
# Word 2067 ("bite") appears 1 time.
# Word 2070 ("boston") appears 1 time.
# Word 2085 ("climb") appears 2 time.
# Word 2104 ("determin") appears 1 time.
# Word 2119 ("eat") appears 1 time.
# Word 2132 ("fli") appears 3 time.
# Word 2136 ("frantic") appears 1 time.
# Word 2175 ("lunch") appears 1 time.
# Word 2211 ("point") appears 1 time.
# Word 2216 ("publish") appears 1 time.
# Word 2230 ("remot") appears 1 time.
# Word 2232 ("rest") appears 1 time.
# Word 2364 ("green") appears 1 time.
# Word 2367 ("hampshir") appears 1 time.
# Word 2393 ("lena") appears 1 time.
# Word 2398 ("magazin") appears 1 time.
# Word 2400 ("main") appears 9 time.
# Word 2418 ("photo") appears 1 time.
# Word 2432 ("read") appears 1 time.
# Word 2476 ("visitor") appears 2 time.
# Word 2517 ("heart") appears 1 time.
# Word 2549 ("thread") appears 1 time.
# Word 2552 ("track") appears 1 time.
# Word 2726 ("footprint") appears 2 time.
# Word 2732 ("globe") appears 2 time.
# Word 2780 ("rescu") appears 1 time.
# Word 2782 ("reviv") appears 1 time.
# Word 2800 ("stream") appears 3 time.
# Word 2804 ("surviv") appears 1 time.
# Word 2932 ("page") appears 1 time.
# Word 2942 ("radio") appears 1 time.
# Word 2972 ("vacat") appears 1 time.
# Word 2996 ("lift") appears 1 time.
# Word 3004 ("sneaker") appears 1 time.
# Word 3050 ("disori") appears 1 time.
# Word 3054 ("dust") appears 1 time.
# Word 3215 ("pretti") appears 1 time.
# Word 3239 ("thoma") appears 1 time.
# Word 3240 ("transport") appears 1 time.
# Word 3324 ("object") appears 1 time.
# Word 3347 ("recogn") appears 1 time.
# Word 3389 ("couldn") appears 1 time.
# Word 3391 ("daili") appears 2 time.
# Word 3434 ("pant") appears 1 time.
# Word 3473 ("cleric") appears 1 time.
# Word 3527 ("fair") appears 1 time.
# Word 3533 ("rain") appears 1 time.
# Word 3542 ("temperatur") appears 1 time.
# Word 3571 ("divis") appears 1 time.
# Word 3607 ("reel") appears 1 time.
# Word 3609 ("ryan") appears 3 time.
# Word 3642 ("headlin") appears 2 time.
# Word 3697 ("disappear") appears 1 time.
# Word 3709 ("human") appears 1 time.
# Word 3748 ("scratch") appears 2 time.
# Word 3754 ("stone") appears 1 time.
# Word 3768 ("youth") appears 1 time.
# Word 3772 ("afternoon") appears 1 time.
# Word 3778 ("campbel") appears 1 time.
# Word 3792 ("drag") appears 1 time.
# Word 3801 ("funni") appears 1 time.
# Word 3827 ("moss") appears 1 time.
# Word 3828 ("nake") appears 1 time.
# Word 3836 ("peak") appears 1 time.
# Word 4015 ("advic") appears 1 time.
# Word 4051 ("germani") appears 1 time.
# Word 4055 ("hero") appears 1 time.
# Word 4095 ("shut") appears 1 time.
# Word 4128 ("colonel") appears 1 time.
# Word 4146 ("enlist") appears 1 time.
# Word 4167 ("lieuten") appears 1 time.
# Word 4203 ("yell") appears 2 time.
# Word 4232 ("theater") appears 1 time.
# Word 4233 ("town") appears 1 time.
# Word 4254 ("circl") appears 1 time.
# Word 4318 ("navi") appears 2 time.
# Word 4356 ("summit") appears 1 time.
# Word 4397 ("guid") appears 1 time.
# Word 4404 ("joan") appears 1 time.
# Word 4463 ("lash") appears 1 time.
# Word 4554 ("plane") appears 1 time.
# Word 4628 ("telephon") appears 2 time.
# Word 4695 ("ranger") appears 1 time.
# Word 4803 ("despond") appears 1 time.
# Word 4923 ("sink") appears 2 time.
# Word 4930 ("accompani") appears 1 time.
# Word 5048 ("doubl") appears 1 time.
# Word 5073 ("stiffen") appears 1 time.
# Word 5312 ("medal") appears 1 time.
# Word 5340 ("stadium") appears 1 time.
# Word 5614 ("georgia") appears 1 time.
# Word 5689 ("scout") appears 2 time.
# Word 5712 ("exploit") appears 1 time.
# Word 5740 ("bishop") appears 1 time.
# Word 5765 ("mama") appears 1 time.
# Word 5769 ("mouth") appears 1 time.
# Word 5787 ("somebodi") appears 1 time.
# Word 5844 ("western") appears 1 time.
# Word 5902 ("cabin") appears 2 time.
# Word 5925 ("curl") appears 1 time.
# Word 5943 ("faint") appears 1 time.
# Word 5951 ("forestri") appears 1 time.
# Word 5981 ("jean") appears 1 time.
# Word 5997 ("moos") appears 1 time.
# Word 6006 ("nose") appears 1 time.
# Word 6116 ("ear") appears 1 time.
# Word 6189 ("award") appears 1 time.
# Word 6254 ("battalion") appears 1 time.
# Word 6270 ("coffe") appears 1 time.
# Word 6302 ("envelop") appears 1 time.
# Word 6316 ("fort") appears 1 time.
# Word 6533 ("judith") appears 1 time.
# Word 6721 ("conner") appears 1 time.
# Word 6729 ("franklin") appears 1 time.
# Word 6742 ("lighter") appears 1 time.
# Word 6772 ("script") appears 1 time.
# Word 6883 ("denni") appears 1 time.
# Word 6992 ("ought") appears 1 time.
# Word 7176 ("ordeal") appears 1 time.
# Word 7296 ("cautionari") appears 1 time.
# Word 7368 ("tommi") appears 1 time.
# Word 7609 ("hallucin") appears 1 time.
# Word 7617 ("pray") appears 1 time.
# Word 7731 ("eyebrow") appears 1 time.
# Word 7801 ("swell") appears 1 time.
# Word 7991 ("limb") appears 1 time.
# Word 8104 ("sheer") appears 1 time.
# Word 8188 ("twin") appears 1 time.
# Word 8214 ("graphic") appears 1 time.
# Word 8505 ("homemak") appears 1 time.
# Word 8615 ("brink") appears 1 time.
# Word 8634 ("miracl") appears 1 time.
# Word 8728 ("prayer") appears 1 time.
# Word 8923 ("cruelli") appears 1 time.
# Word 8992 ("newport") appears 1 time.
# Word 9108 ("airwav") appears 1 time.
# Word 9370 ("dig") appears 1 time.
# Word 9455 ("condon") appears 1 time.
# Word 9507 ("insect") appears 1 time.
# Word 9737 ("hitler") appears 1 time.
# Word 9739 ("overhead") appears 1 time.
# Word 9743 ("sneez") appears 1 time.
# Word 9816 ("schoolchildren") appears 1 time.
# Word 10187 ("soup") appears 1 time.
# Word 10334 ("forag") appears 1 time.
# Word 10377 ("mat") appears 1 time.
# Word 10430 ("slop") appears 1 time.
# Word 10820 ("berri") appears 2 time.
# Word 10833 ("soak") appears 1 time.
# Word 10852 ("legion") appears 1 time.
# Word 10907 ("yanke") appears 1 time.
# Word 10935 ("tenn") appears 1 time.
# Word 10971 ("ninth") appears 1 time.
# Word 11025 ("roosevelt") appears 1 time.
# Word 11151 ("bean") appears 1 time.
# Word 11205 ("mist") appears 2 time.
# Word 11251 ("rejoin") appears 1 time.
# Word 11275 ("hampton") appears 1 time.
# Word 11631 ("adolesc") appears 1 time.
# Word 12315 ("lynn") appears 1 time.
# Word 12330 ("crawl") appears 1 time.
# Word 12380 ("airborn") appears 1 time.
# Word 12439 ("cano") appears 2 time.
# Word 12875 ("gehrig") appears 1 time.
# Word 13281 ("odyssey") appears 1 time.
# Word 13654 ("screech") appears 1 time.
# Word 13656 ("beret") appears 1 time.
# Word 13944 ("mosquito") appears 1 time.
# Word 14004 ("millionth") appears 1 time.
# Word 14162 ("luckiest") appears 1 time.
# Word 14231 ("weeklong") appears 1 time.
# Word 14274 ("monopol") appears 1 time.
# Word 14291 ("misjudg") appears 1 time.
# Word 14384 ("forehead") appears 1 time.
# Word 15205 ("baxter") appears 1 time.
# Word 15497 ("valor") appears 1 time.
# Word 15624 ("teeter") appears 1 time.
# Word 16139 ("precipic") appears 1 time.
# Word 16386 ("eaton") appears 1 time.
# Word 16448 ("turnstil") appears 1 time.
# Word 16873 ("bangor") appears 4 time.
# Word 17100 ("deliri") appears 1 time.
# Word 17312 ("bridget") appears 1 time.

# %%
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.026770545983534913),
#  (1, 0.029068893675775774),
#  (2, 0.23280474767240217),
#  (3, 0.0318152884632238),
#  (4, 0.03317955987601938),
#  (5, 0.028340257009214845),
#  (6, 0.011822358013442068),
#  (7, 0.03651313378109811),
#  (8, 0.03134841141839632),
#  (9, 0.08219950978886159),
#  (10, 0.11833316065832819),
#  (11, 0.1068948542622624),
#  (12, 0.029414800654264807),
#  (13, 0.03979115382242141),
#  (14, 0.034294964747078195),
#  (15, 0.03491551839627701),
#  (16, 0.028504937535025775),
#  (17, 0.04794320784817166),
#  (18, 0.0430859100761559),
#  (19, 0.03715714840084949),
#  (20, 0.052708727883302366),
#  (21, 0.05897435106024678),
#  (22, 0.19674943192832461),
#  (23, 0.03565688419697066),
#  (24, 0.03846151024366051),
#  (25, 0.16461063075731858),
#  (26, 0.06336353656669406),
#  (27, 0.06766757634740564),
#  (28, 0.04165525415334854),
#  (29, 0.028027620454488433),
#  (30, 0.02319742916334767),
#  (31, 0.03607625005938099),
#  (32, 0.04023225268361473),
#  (33, 0.05157570903473344),
#  (34, 0.044666235535910065),
#  (35, 0.043254521458515965),
#  (36, 0.02519874566999445),
#  (37, 0.01900049176269584),
#  (38, 0.023721531944358117),
#  (39, 0.035013072915119174),
#  (40, 0.053070428907241465),
#  (41, 0.04145693954158792),
#  (42, 0.06166694247724679),
#  (43, 0.12369662016428726),
#  (44, 0.09480847802749506),
#  (45, 0.03471410699031352),
#  (46, 0.02313611276564623),
#  (47, 0.020633324431933955),
#  (48, 0.09021676955018604),
#  (49, 0.03324966176585171),
#  (50, 0.03890920772757225),
#  (51, 0.01359866619171774),
#  (52, 0.02082456317382053),
#  (53, 0.051185484085302456),
#  (54, 0.04313431595700963),
#  (55, 0.03304074997193685),
#  (56, 0.020191591057242515),
#  (57, 0.019814939145273887),
#  (58, 0.039460885775158494),
#  (59, 0.0539775445489154),
#  (60, 0.02419900255248547),
#  (61, 0.026258647661580488),
#  (62, 0.037737606112968905),
#  (63, 0.03856956216630936),
#  (64, 0.021702877203665018),
#  (65, 0.05365456356139323),
#  (66, 0.03815191892122022),
#  (67, 0.021198792893950283),
#  (68, 0.033065402739105645),
#  (69, 0.10937510519415207),
#  (70, 0.03989495422942216),
#  (71, 0.028865388605976455),
#  (72, 0.06500582156991412),
#  (73, 0.02890511079650124),
#  (74, 0.011470765570106805),
#  (75, 0.026765138816566295),
#  (76, 0.04450290814818994),
#  (77, 0.04092040325645406),
#  (78, 0.043877484169283436),
#  (79, 0.01967814883810411),
#  (80, 0.015597377774923045),
# Topic: 8 Word: 0.005*"compani" + 0.004*"market" + 0.003*"bank" + 0.003*"health" + 0.003*"price" + 0.003*"fund" + 0.003*"billion" + 0.003*"investor" + 0.003*"invest" + 0.003*"trump"
# Topic: 9 Word: 0.007*"student" + 0.005*"school" + 0.004*"biden" + 0.003*"fisher" + 0.003*"gawker" + 0.003*"facebook" + 0.002*"univers" + 0.002*"campus" + 0.002*"devo" + 0.002*"trump"

# %%
processed_docs[4310]
# Out:
# ['juli',
#  'world',
#  'teeter',
#  'brink',
#  'hitler',
#  'menac',
#  'poland',
#  'millionth',
#  'visitor',
#  'pass',
#  'turnstil',
#  'york',
#  'world',
#  'fair',
#  'basebal',
#  'fan',
#  'reel',
#  'gehrig',
#  'luckiest',
#  'speech',
#  'yanke',
#  'stadium',
#  'american',
#  'think',
#  'donn',
#  'fendler',
#  'lose',
#  'mount',
#  'katahdin',
#  'main',
#  'object',
#  'frantic',
#  'search',
#  'rescu',
#  'oper',
#  'drag',
#  'day',
#  'monopol',
#  'radio',
#  'airwav',
#  'newspap',
#  'headlin',
#  'thousand',
#  'mother',
#  'send',
#  'prayer',
#  'western',
#  'union',
#  'mother',
#  'scout',
#  'join',
#  'search',
#  'worker',
#  'millinocket',
#  'paper',
#  'york',
#  'state',
#  'polic',
#  'dispatch',
#  'best',
#  'bloodhound',
#  'heart',
#  'sink',
#  'donn',
#  'footprint',
#  'disappear',
#  'edg',
#  'sheer',
#  'precipic',
#  'call',
#  'saddl',
#  'slip',
#  'tri',
#  'believ',
#  'faint',
#  'thread',
#  'hope',
#  'despond',
#  'father',
#  'donald',
#  'tell',
#  'boston',
#  'globe',
#  'spirit',
#  'lift',
#  'footprint',
#  'appear',
#  'near',
#  'mountain',
#  'base',
#  'day',
#  'later',
#  'final',
#  'ninth',
#  'miracl',
#  'strip',
#  'nake',
#  'day',
#  'fear',
#  'battl',
#  'main',
#  'wilder',
#  'slop',
#  'mount',
#  'katahdin',
#  'donn',
#  'fendler',
#  'come',
#  'civil',
#  'afternoon',
#  'cruelli',
#  'bite',
#  'scratch',
#  'deliri',
#  'hear',
#  'human',
#  'voic',
#  'globe',
#  'report',
#  'juli',
#  'headlin',
#  'main',
#  'wild',
#  'nation',
#  'ordeal',
#  'donn',
#  'fendler',
#  'die',
#  'sunday',
#  'bangor',
#  'denni',
#  'say',
#  'fendler',
#  'fendler',
#  'spend',
#  'previous',
#  'summer',
#  'vacat',
#  'sebasticook',
#  'lake',
#  'newport',
#  'center',
#  'main',
#  'juli',
#  'donald',
#  'fendler',
#  'son',
#  'ryan',
#  'donn',
#  'tommi',
#  'donn',
#  'twin',
#  'head',
#  'lunch',
#  'ascend',
#  'mount',
#  'katahdin',
#  'feet',
#  'state',
#  'highest',
#  'peak',
#  'accompani',
#  'henri',
#  'condon',
#  'local',
#  'guid',
#  'fred',
#  'eaton',
#  'young',
#  'famili',
#  'friend',
#  'eager',
#  'climb',
#  'donn',
#  'leav',
#  'father',
#  'brother',
#  'push',
#  'henri',
#  'fred',
#  'weather',
#  'reach',
#  'summit',
#  'mist',
#  'close',
#  'shut',
#  'view',
#  'mountain',
#  'say',
#  'lose',
#  'mountain',
#  'main',
#  'account',
#  'adventur',
#  'write',
#  'joseph',
#  'egan',
#  'ignor',
#  'advic',
#  'climb',
#  'mat',
#  'donn',
#  'head',
#  'rejoin',
#  'famili',
#  'lash',
#  'rain',
#  'disori',
#  'envelop',
#  'mist',
#  'quick',
#  'lose',
#  'begin',
#  'weeklong',
#  'odyssey',
#  'recal',
#  'scout',
#  'train',
#  'decid',
#  'follow',
#  'small',
#  'stream',
#  'hop',
#  'camp',
#  'town',
#  'night',
#  'curl',
#  'tree',
#  'root',
#  'cover',
#  'moss',
#  'wild',
#  'berri',
#  'second',
#  'trip',
#  'walk',
#  'stream',
#  'lose',
#  'sneaker',
#  'tie',
#  'carri',
#  'shoulder',
#  'long',
#  'tri',
#  'throw',
#  'soak',
#  'jean',
#  'rock',
#  'stream',
#  'misjudg',
#  'watch',
#  'water',
#  'carri',
#  'away',
#  'couldn',
#  'believ',
#  'recal',
#  'book',
#  'pant',
#  'go',
#  'like',
#  'kewpi',
#  'small',
#  'stone',
#  'feet',
#  'temperatur',
#  'night',
#  'stiffen',
#  'limb',
#  'mosquito',
#  'black',
#  'fli',
#  'moos',
#  'fli',
#  'somebodi',
#  'ought',
#  'black',
#  'fli',
#  'fendler',
#  'say',
#  'lose',
#  'mountain',
#  'main',
#  'terribl',
#  'forehead',
#  'hair',
#  'eyebrow',
#  'corner',
#  'eye',
#  'corner',
#  'mouth',
#  'nose',
#  'like',
#  'dust',
#  'sneez',
#  'dig',
#  'ear',
#  'pray',
#  'hallucin',
#  'hear',
#  'plane',
#  'circl',
#  'overhead',
#  'clear',
#  'wave',
#  'twice',
#  'encount',
#  'bear',
#  'forag',
#  'berri',
#  'begin',
#  'lose',
#  'strength',
#  'hope',
#  'sight',
#  'telephon',
#  'wire',
#  'suggest',
#  'right',
#  'track',
#  'juli',
#  'come',
#  'clear',
#  'lake',
#  'cano',
#  'small',
#  'cabin',
#  'remot',
#  'camp',
#  'east',
#  'branch',
#  'penobscot',
#  'river',
#  'nelson',
#  'mcmoarn',
#  'mcmoarn',
#  'emerg',
#  'cabin',
#  'doubl',
#  'crawl',
#  'begin',
#  'yell',
#  'fendler',
#  'say',
#  'book',
#  'guess',
#  'yell',
#  'pretti',
#  'funni',
#  'mcmoarn',
#  'tell',
#  'later',
#  'sound',
#  'like',
#  'screech',
#  'carri',
#  'lena',
#  'mcmoarn',
#  'nelson',
#  'wife',
#  'reviv',
#  'coffe',
#  'soup',
#  'donn',
#  'hand',
#  'telephon',
#  'receiv',
#  'mother',
#  'line',
#  'mama',
#  'right',
#  'tell',
#  'scratch',
#  'swell',
#  'eat',
#  'aliv',
#  'insect',
#  'pound',
#  'lighter',
#  'wander',
#  'mile',
#  'start',
#  'point',
#  'aliv',
#  'news',
#  'page',
#  'york',
#  'time',
#  'fold',
#  'life',
#  'magazin',
#  'publish',
#  'photo',
#  'spread',
#  'littl',
#  'year',
#  'later',
#  'donn',
#  'white',
#  'hous',
#  'presid',
#  'franklin',
#  'roosevelt',
#  'award',
#  'armi',
#  'navi',
#  'legion',
#  'valor',
#  'medal',
#  'recogn',
#  'outstand',
#  'youth',
#  'hero',
#  'donn',
#  'conner',
#  'fendler',
#  'bear',
#  'father',
#  'help',
#  'famili',
#  'busi',
#  'almi',
#  'cleric',
#  'vestment',
#  'church',
#  'good',
#  'mother',
#  'ruth',
#  'ryan',
#  'homemak',
#  'transport',
#  'cano',
#  'mcmoarn',
#  'camp',
#  'grindston',
#  'spend',
#  'day',
#  'hospit',
#  'bangor',
#  'donn',
#  'quick',
#  'resum',
#  'adolesc',
#  'routin',
#  'graduat',
#  'hampton',
#  'school',
#  'hampshir',
#  'enlist',
#  'navi',
#  'serv',
#  'seabe',
#  'pacif',
#  'theater',
#  'world',
#  'studi',
#  'forestri',
#  'univers',
#  'main',
#  'year',
#  'briefli',
#  'attend',
#  'univers',
#  'georgia',
#  'make',
#  'career',
#  'armi',
#  'train',
#  'green',
#  'beret',
#  'serv',
#  'vietnam',
#  'airborn',
#  'divis',
#  'post',
#  'west',
#  'germani',
#  'rank',
#  'lieuten',
#  'colonel',
#  'later',
#  'assum',
#  'command',
#  'battalion',
#  'fort',
#  'campbel',
#  'retir',
#  'move',
#  'clarksvill',
#  'tenn',
#  'armi',
#  'base',
#  'addit',
#  'surviv',
#  'daughter',
#  'bridget',
#  'fendler',
#  'judith',
#  'king',
#  'joan',
#  'bedwel',
#  'brother',
#  'ryan',
#  'thoma',
#  'grandchildren',
#  'rest',
#  'life',
#  'fendler',
#  'spend',
#  'summer',
#  'main',
#  'fall',
#  'visit',
#  'school',
#  'talk',
#  'exploit',
#  'wood',
#  'hope',
#  'messag',
#  'sink',
#  'tell',
#  'bangor',
#  'daili',
#  'news',
#  'faith',
#  'determin',
#  'messag',
#  'visitor',
#  'baxter',
#  'state',
#  'park',
#  'hear',
#  'stori',
#  'cautionari',
#  'tale',
#  'ranger',
#  'know',
#  'year',
#  'book',
#  'requir',
#  'read',
#  'main',
#  'schoolchildren',
#  'fendler',
#  'tell',
#  'stori',
#  'graphic',
#  'novel',
#  'lose',
#  'trail',
#  'script',
#  'lynn',
#  'plourd',
#  'illustr',
#  'bishop',
#  'ash',
#  'go',
#  'mount',
#  'katahdin',
#  'tell',
#  'bangor',
#  'daili',
#  'news',
#  'brother',
#  'say',
#  'continu',
#  'go',
#  'bean']

# %%
for index, score in sorted(lda_model[bow_corpus[4310]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.5887055397033691
# Topic: 0.005*"go" + 0.005*"know" + 0.005*"play" + 0.005*"game" + 0.005*"tell" + 0.004*"come" + 0.004*"film" + 0.004*"star" + 0.004*"love" + 0.004*"think"
#
# Score: 0.3047526180744171
# Topic: 0.005*"go" + 0.005*"work" + 0.005*"world" + 0.004*"think" + 0.004*"build" + 0.004*"look" + 0.004*"come" + 0.004*"know" + 0.004*"team" + 0.004*"water"
#
# Score: 0.061553653329610825
# Topic: 0.017*"polic" + 0.011*"attack" + 0.009*"offic" + 0.008*"kill" + 0.007*"report" + 0.007*"isi" + 0.006*"shoot" + 0.006*"tell" + 0.005*"group" + 0.005*"state"
#
# Score: 0.04380832612514496
# Topic: 0.009*"health" + 0.006*"drug" + 0.005*"case" + 0.005*"medic" + 0.005*"tell" + 0.005*"children" + 0.005*"care" + 0.005*"women" + 0.004*"famili" + 0.004*"know"

# %%
for index, score in sorted(lda_model_tfidf[bow_corpus[4310]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.8587159514427185
# Topic: 0.005*"polic" + 0.003*"shoot" + 0.002*"offic" + 0.002*"citi" + 0.002*"store" + 0.002*"kill" + 0.001*"counti" + 0.001*"arrest" + 0.001*"uber" + 0.001*"home"
#
# Score: 0.07600127905607224
# Topic: 0.005*"appl" + 0.004*"game" + 0.003*"film" + 0.002*"season" + 0.002*"team" + 0.002*"movi" + 0.002*"player" + 0.002*"play" + 0.002*"star" + 0.002*"iphon"
#
# Score: 0.034065697342157364
# Topic: 0.007*"trump" + 0.004*"clinton" + 0.003*"milo" + 0.002*"women" + 0.002*"donald" + 0.002*"twitter" + 0.002*"hillari" + 0.002*"presid" + 0.002*"yiannopoulo" + 0.002*"obama"
#
# Score: 0.030035046860575676
# Topic: 0.009*"trump" + 0.007*"clinton" + 0.005*"poll" + 0.004*"vote" + 0.004*"republican" + 0.004*"voter" + 0.004*"cruz" + 0.004*"campaign" + 0.004*"parti" + 0.003*"elect"

# %%
unseen_document = 'How a Pentagon deal became an identity crisis for Google'
bow_vector = dictionary.doc2bow(preprocess(unseen_document))
for index, score in sorted(lda_model[bow_vector], key=lambda tup: -1*tup[1]):
    print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
# Out:
# Score: 0.6424863338470459	 Topic: 0.010*"state" + 0.008*"countri" + 0.008*"govern" + 0.006*"american" + 0.005*"polici"
# Score: 0.22413262724876404	 Topic: 0.009*"report" + 0.008*"email" + 0.008*"facebook" + 0.007*"student" + 0.007*"news"
# Score: 0.016675977036356926	 Topic: 0.017*"compani" + 0.009*"busi" + 0.008*"market" + 0.007*"million" + 0.006*"price"
# Score: 0.016672976315021515	 Topic: 0.014*"state" + 0.008*"north" + 0.007*"court" + 0.006*"korea" + 0.005*"report"
# Score: 0.016672879457473755	 Topic: 0.040*"trump" + 0.016*"clinton" + 0.013*"presid" + 0.010*"republican" + 0.009*"campaign"
# Score: 0.016672739759087563	 Topic: 0.017*"polic" + 0.011*"attack" + 0.009*"offic" + 0.008*"kill" + 0.007*"report"
# Score: 0.016672534868121147	 Topic: 0.017*"trump" + 0.007*"think" + 0.007*"news" + 0.007*"white" + 0.007*"media"
# Score: 0.0166714396327734	 Topic: 0.009*"health" + 0.006*"drug" + 0.005*"case" + 0.005*"medic" + 0.005*"tell"
# Score: 0.016671346500515938	 Topic: 0.005*"go" + 0.005*"work" + 0.005*"world" + 0.004*"think" + 0.004*"build"
# Score: 0.016671188175678253	 Topic: 0.005*"go" + 0.005*"know" + 0.005*"play" + 0.005*"game" + 0.005*"tell"
